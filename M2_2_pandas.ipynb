# %% [markdown]
# ![](images/ds_rural.png)

# %% [markdown]
# # Módulo 2

# %% [markdown]
# ## Pandas

# %%
#Numpy I: array, slicing, fancy index, copy and view
Pandas I: dataframes, series, index, Pandas I/O (csv, json, excell)
Prática dos conteúdos estudados: Processando e extraindo informações de arquivos csv
